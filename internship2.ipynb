# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import sys
import random
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import recall_score, accuracy_score, f1_score, precision_score
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt

# %%
df7 = pd.read_excel('Охраняемые территории.xls')
df8 = pd.read_excel('Земельные участки.xls')
df9 = pd.read_excel('Только  лес.xls')

# %%
df7
# Out:
#    year  value
# 0  2014   11.8
# 1  2015   12.1
# 2  2016   12.4
# 3  2017   12.4
# 4  2018   13.9
# 5  2019   13.9
# 6  2020   14.0

# %%
# %matplotlib inline

# %%
from matplotlib.ticker import MultipleLocator
columns = df7.columns
plt.xticks(df7.year)
for i in range(1, len(columns)):
    plt.plot(df7.year, df7[columns[i]])
label = ['Доля']    
#ax.plt(labels= label, autopct='%1.2f%%')
#plt.legend(label)
plt.ylabel('%', fontsize=10) # добавляем подпись к оси ординат "ось y"
plt.xlabel('Год', fontsize=10) # добавляем подпись к оси ординат "ось y"
plt.grid()
plt.title(r'Доля площади особо охраняемых природных территорий федерального,',fontsize=9.5, y=1.1, loc = 'center')
plt.suptitle(r'регионального и местного значения в общей площади территории страны', fontsize=9.5, y=0.95)
plt.show()

# %%
from matplotlib.ticker import MultipleLocator
columns = df8.columns
plt.xticks(df8.year)
for i in range(1, len(columns)):
    plt.plot(df8.year, df8[columns[i]])
plt.ylabel('%', fontsize=10) # добавляем подпись к оси ординат "ось y"
plt.xlabel('Год', fontsize=10) # добавляем подпись к оси ординат "ось y"
plt.grid()
plt.title(r'Площадь земельных участков, расположенных в границах лесничеств,',fontsize=9.5, y=1.1, loc = 'center') 
plt.suptitle(r'в процентном отношении к площади земель всех категорий (15.1.1)',fontsize=9.5, y=0.95)
plt.show()

# %%
from matplotlib.ticker import MultipleLocator
columns = df9.columns
plt.xticks(df9.year)
for i in range(1, len(columns)):
    plt.plot(df9.year, df9[columns[i]])
label = ['Доля']    
plt.ylabel('%', fontsize=10) # добавляем подпись к оси ординат "ось y"
plt.xlabel('Год', fontsize=10) # добавляем подпись к оси ординат "ось y"
plt.grid()
plt.title(r'Доля лесных площадей в пределах установленных',fontsize=9.5, y=1.1, loc = 'center') 
plt.suptitle(r' законом охраняемых территорий',fontsize=9.5, y=0.95)
plt.show()

# %%
df10 = pd.read_excel('расходы правительства -.xls')
df11 = pd.read_excel('расходы правительства.xls')
df13 = pd.read_excel('расходы правительства2.xlsx')
df12 = pd.read_excel('Правозащитный институт.xls')

# %%
df10
# Out:
#    Year  Национальная безопасность и правоохранительная деятельность   \
# 0  2017                                              99.43
# 1  2018                                              96.18
# 2  2019                                              94.40
# 3  2020                                              91.60
#
#    Национальная оборона  Национальная экономика  Общегосударственные вопросы
# 0                100.58                  109.37                        95.99
# 1                102.10                  101.05                        96.48
# 2                102.43                  107.39                        96.03
# 3                102.60                  131.10                        96.80

# %%
from matplotlib.ticker import MultipleLocator
columns = df10.columns
plt.xticks(df10.Year)
label = ['Нац. безопасность и правоохранительная деятельность', 'Нац. оборона', 'Нац. экономика','Общегосударственные вопросы ']    
for i in range(1, len(columns)):
    plt.plot(df10.Year, df10[columns[i]])
plt.ylabel('%', fontsize=10) # добавляем подпись к оси ординат "ось y"
plt.xlabel('Год', fontsize=10) # добавляем подпись к оси ординат "ось y"
plt.legend(label, loc='best')
plt.grid()
plt.title(r'Первичные расходы Правительства РФ в процентном отношении к ',fontsize=9.5, y=1.1, loc = 'center') 
plt.suptitle(r'первоначальному утвержденному бюджету в разбивке по секторам',fontsize=9.5, y=0.95)
plt.show()

# %%
from matplotlib.ticker import MultipleLocator
columns = df13.columns
plt.xticks(df13.Year)
label = ['ЖКХ', 'Здравоохранение', 'Культура, кинематография','Образование','Социальная политика', 'СМИ','Физкультура и спорт' ]    
for i in range(1, len(columns)):
    plt.plot(df13.Year, df13[columns[i]])
plt.ylabel('%', fontsize=10) # добавляем подпись к оси ординат "ось y"
plt.xlabel('Год', fontsize=10) # добавляем подпись к оси ординат "ось y"
plt.legend(label, loc='upper left')
plt.grid()
plt.title(r'Первичные расходы Правительства РФ в процентном отношении к ',fontsize=9.5, y=1.1, loc = 'center') 
plt.suptitle(r'первоначальному утвержденному бюджету в разбивке по секторам',fontsize=9.5, y=0.95)
plt.show()

# %%
from matplotlib.ticker import MultipleLocator
columns = df12.columns
plt.xticks(df12.year)
for i in range(1, len(columns)):
    plt.plot(df12.year, df12[columns[i]])
plt.xlabel('Год', fontsize=10) # добавляем подпись к оси ординат "ось y"
plt.grid()
plt.title(r'Наличие независимых национальных правозащитных институтов,',fontsize=9.5, y=1.1, loc = 'center') 
plt.suptitle(r'действующих в соответствии с Парижскими принципами (1 - в наличии)',fontsize=9.5, y=0.95)
plt.show()

# %%
import matplotlib.pyplot as plt
values1 = [0.66,99.34]  
explode = (0, 1.1)
label = ['Живущие в аварийных домах']
sizes = [15, 30, 45, 10]
colors = ( "red", "green") 
plt.show()
fig, (ax1) = plt.subplots(1)
ax1.pie(values1, colors = colors, explode=explode,radius=1.2, autopct='%1.2f%%')
ax1.legend(labels = label, loc='upper left')
plt.title(r'Доля городского населения, проживающего в аварийном жилищном фонде,',fontsize=10, y=1.1, loc = 'center' )
plt.suptitle(r' в общей численности городского населения (2019 год)',fontsize=10, y=0.95)
plt.show()

# %%
df20 = pd.read_excel('ввод жилья.xls')

# %%
from matplotlib.ticker import MultipleLocator
columns = df20.columns
plt.xticks(df20.year)
label = ['Всего', 'Городская  местность', 'Сельская местность']    
for i in range(1, len(columns)):
    plt.plot(df20.year, df20[columns[i]])
plt.ylabel('%', fontsize=10) # добавляем подпись к оси ординат "ось y"
plt.xlabel('Год', fontsize=10) # добавляем подпись к оси ординат "ось y"
plt.legend(label, loc='best')
plt.grid()
plt.title(r'Соотношение темпа ввода в действие жилых домов к темпу роста населения',fontsize=9.5, y=1.0, loc = 'center') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-49bb0f479637> in <module>
#       1 from matplotlib.ticker import MultipleLocator
# ----> 2 columns = df20.columns
#       3 plt.xticks(df20.year)
#       4 label = ['Всего', 'Городская  местность', 'Сельская местность']
#       5 for i in range(1, len(columns)):
#
# NameError: name 'df20' is not defined
